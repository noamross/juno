# %% [markdown]
# This is some ***markdown***.  abcdefghijklmnopqrstuvwxyz 1234567890 ABCDEFGHIJKLMNOPQRSTUVWXYZ l1|oO0 (){}[]<> abcdefghijklmnopqrstuvwxyz 1234567890 ABCDEFGHIJKLMNOPQRSTUVWXYZ l1|oO0 (){}[]<>
#
# Hello There
#
# Wow

# %% [raw]
# Raw data here

# %%
a = 1+ 1; b = a + 2
plot(2,2)
